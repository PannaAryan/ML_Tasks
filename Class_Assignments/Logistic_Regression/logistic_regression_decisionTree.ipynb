# %% [markdown]
# Import Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier, export_text
from sklearn import tree
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Dataset Access

# %%
data = pd.read_csv('/content/drive/MyDrive/ML/data.txt', header=None, names=['X1', 'X2', 'y'])

X, y = data[['X1', 'X2']].values, data['y'].values

# %% [markdown]
# Logistic Regression

# %%
logistic_regression_model = LogisticRegression()
logistic_regression_model.fit(X, y)

# Plot Logistic Regression Decision Boundary
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)

# Using 'viridis' colormap
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.viridis)
plt.title('Logistic Regression Decision Boundary - Viridis Colormap')

xx, yy = np.meshgrid(np.linspace(X[:, 0].min(), X[:, 0].max(), 100),
                     np.linspace(X[:, 1].min(), X[:, 1].max(), 100))
Z = logistic_regression_model.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

# Using 'plasma' colormap for contourf
plt.contourf(xx, yy, Z, alpha=0.3, cmap=plt.cm.plasma)
plt.show()

# %% [markdown]
# Decision tree model

# %%
decision_tree_model = DecisionTreeClassifier()
decision_tree_model.fit(X, y)

# Plot Decision Tree
plt.figure(figsize=(16, 4))

# Scatter plot using 'PuBuGn' colormap
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.PuBuGn)
plt.title('Custom Decision Tree Decision Boundary - PuBuGn Colormap')

xx, yy = np.meshgrid(np.linspace(X[:, 0].min(), X[:, 0].max(), 100),
                     np.linspace(X[:, 1].min(), X[:, 1].max(), 100))
Z = decision_tree_model.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

# Contour plot using 'YlOrRd' colormap
plt.contourf(xx, yy, Z, alpha=0.3, cmap=plt.cm.PuBuGn)

# Display decision tree without subplot
tree.plot_tree(decision_tree_model, filled=True, feature_names=['X1', 'X2'], class_names=['Negative', 'Positive'])
plt.title('Decision Tree')
plt.show()
